# %% [markdown]
# <a href="https://colab.research.google.com/github/tharun-229/-AIML/blob/main/Assigment%201%5Bpart-2%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
people = ['Ann', 'Brandon', 'Chen', 'David', 'Emily', 'Farook',
          'Gagan', 'Hamish', 'Imran', 'Julio', 'Katherine', 'Lily']
age = [21, 12, 32, 45, 37, 18, 28, 52, 5, 40, 48, 15]
weight = [55, 35, 77, 68, 70, 60, 72, 69, 18, 65, 82, 48]
height = [160, 135, 170, 165, 173, 168, 175, 159, 105, 171, 155, 158]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(weight,height)
plt.title("Relationship betwwn Weight and Height of patients")
plt.ylabel("Height in Meters")
plt.xlabel("Weight of paitients in Kgs")
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.title("People's weight in Kgs",fontsize=16,fontstyle='italic')

#Main plot function 'bar'
plt.bar(x=people,height=weight,width=0.6,color='blue',edgecolor='k',alpha=0.6)

plt.xlabel("People",fontsize=15)
plt.xticks(fontsize=14,rotation=30)
plt.yticks(fontsize=14)
plt.ylabel("Weight(in Kgs)",fontsize=15)
plt.show()

# %%
import numpy as np
plt.figure(figsize=(7,5))

#Main plot function 'hist
plt.hist(weight,color='green',edgecolor='black',alpha=0.75,bins=5)

plt.title("Histrogram of patient weight",fontsize=18)
plt.xlabel("Weight in Kgs",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()
